# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dati=pd.read_csv("dati.csv",sep=";",low_memory=False)
dati.head()
# Out:
#   DataRilevazione DataProtocollo DataAccadimento DataDefinizione DataMorte  \
# 0      30/04/2018     29/10/2013      24/10/2013      14/11/2013       NaN
# 1      30/04/2018     14/10/2013      09/10/2013      19/11/2013       NaN
# 2      30/04/2018     29/10/2014      28/10/2014      17/11/2014       NaN
# 3      30/04/2018     28/07/2014      27/07/2014      13/08/2014       NaN
# 4      30/04/2018     28/01/2014      23/01/2014      25/03/2014       NaN
#
#    LuogoAccadimento  IdentificativoInfortunato Genere  Eta LuogoNascita  \
# 0               108                    7521278      M   38         ITAL
# 1               108                    6299200      M   27         ITAL
# 2                17                   11656130      M   50         ITAL
# 3                16                   11491384      F   42         ITAL
# 4               108                   11230846      F   28         ITAL
#
#             ...           Indennizzo DecisioneIstruttoriaEsitoMortale  \
# ...

# %%
len(dati["DataMorte"].unique())
#I morti sono 615
# Out:
# 615

# %%
dati.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598630 entries, 0 to 598629
# Data columns (total 24 columns):
# DataRilevazione                          598630 non-null object
# DataProtocollo                           598630 non-null object
# DataAccadimento                          598630 non-null object
# DataDefinizione                          593740 non-null object
# DataMorte                                808 non-null object
# LuogoAccadimento                         598630 non-null int64
# IdentificativoInfortunato                598630 non-null int64
# Genere                                   598630 non-null object
# Eta                                      598630 non-null int64
# LuogoNascita                             598630 non-null object
# ModalitaAccadimento                      598630 non-null object
# ConSenzaMezzoTrasporto                   598630 non-null object
# IdentificativoCaso                       598630 non-null int64
# ...
